# %% [markdown]
# # Analítica computacional para la toma de decisiones
#
# Departamento de Ingeniería Industrial
#
# Universidad de los Andes

# %% [markdown]
# Generación de muestras de una variable aleatoria normal usando numpy.

# %%
import numpy as np
#crea datos con beta
a = 5
b = 1
n=1000
vals = np.random.beta(a=a, b=b, size=n)
print(vals)
# Out:
# [0.96742492 0.99249155 0.92013202 0.946484   0.92120312 0.81973042
#  0.64887766 0.76676063 0.79792901 0.69179043 0.85151336 0.71225644
#  0.96239887 0.93672671 0.69047036 0.70310541 0.90976162 0.71738872
#  0.81144565 0.59852672 0.99937735 0.99740211 0.3727853  0.89069939
#  0.93550134 0.78896504 0.83252796 0.90551626 0.86787011 0.59003964
#  0.83603706 0.78409722 0.54688579 0.80524107 0.97006645 0.61003682
#  0.63372476 0.90788164 0.9633735  0.35889888 0.84416695 0.90779762
#  0.86272449 0.97565575 0.57961546 0.78840292 0.99818624 0.84078235
#  0.59627154 0.96810629 0.5470454  0.84999625 0.85887814 0.91231551
#  0.72296858 0.89801378 0.68462275 0.83664742 0.97048544 0.88592664
#  0.91767204 0.91208729 0.91178691 0.93354856 0.98370408 0.95034229
#  0.60469099 0.8699021  0.88987652 0.98790136 0.76070857 0.9481906
#  0.96427191 0.89032183 0.85286379 0.85628379 0.73400757 0.66193603
#  0.98643796 0.21276787 0.81603232 0.97938082 0.68678789 0.91718831
# ...

# %% [markdown]
# Cálculo de estadísticas usando pandas.

# %%
import pandas as pd

df = pd.DataFrame(vals)
print(df.describe())
# Out:
#                  0
# count  1000.000000
# mean      0.832153
# std       0.142088
# min       0.212768
# 25%       0.762857
# 50%       0.868154
# 75%       0.941185
# max       0.999518

# %% [markdown]
# Generación de histograma usando matplotlib.

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(x=vals, bins=100)
plt.title('Histograma de tiempos de servicio')
plt.xlabel('Tiempos de servicio')
plt.ylabel('Frecuencia')
plt.show()

print(bins)
print(count)
# Out:
# [0.21276787 0.22063537 0.22850288 0.23637038 0.24423788 0.25210538
#  0.25997289 0.26784039 0.27570789 0.28357539 0.29144289 0.2993104
#  0.3071779  0.3150454  0.3229129  0.33078041 0.33864791 0.34651541
#  0.35438291 0.36225042 0.37011792 0.37798542 0.38585292 0.39372043
#  0.40158793 0.40945543 0.41732293 0.42519043 0.43305794 0.44092544
#  0.44879294 0.45666044 0.46452795 0.47239545 0.48026295 0.48813045
#  0.49599796 0.50386546 0.51173296 0.51960046 0.52746797 0.53533547
#  0.54320297 0.55107047 0.55893797 0.56680548 0.57467298 0.58254048
#  0.59040798 0.59827549 0.60614299 0.61401049 0.62187799 0.6297455
#  0.637613   0.6454805  0.653348   0.66121551 0.66908301 0.67695051
#  0.68481801 0.69268551 0.70055302 0.70842052 0.71628802 0.72415552
#  0.73202303 0.73989053 0.74775803 0.75562553 0.76349304 0.77136054
#  0.77922804 0.78709554 0.79496305 0.80283055 0.81069805 0.81856555
#  0.82643305 0.83430056 0.84216806 0.85003556 0.85790306 0.86577057
# ...

# %% [markdown]
# Densidad exp con lamda=1

# %%
from scipy.stats import expon
import numpy as np
import matplotlib.pyplot as plt

# exp(1)
x= np.arange(1,10,0.001)
plt.plot(x, expon.pdf(x,a))
plt.title('Función de densidad exp(1)')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %% [markdown]
# Densidad exp con lamda=0.1

# %%
from scipy.stats import expon
import numpy as np
import matplotlib.pyplot as plt

# exp(0.1)
x= np.arange(1,10,0.001)
plt.plot(x, expon.pdf(x,0.1))
plt.title('Función de densidad exp(0.1)')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %% [markdown]
# Densidad exp con lamda=0.5

# %%
from scipy.stats import expon
import numpy as np
import matplotlib.pyplot as plt

# exp(0.5)
x= np.arange(1,10,0.001)
plt.plot(x, expon.pdf(x,0.5))
plt.title('Función de densidad exp(0.5)')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %% [markdown]
# QQ plot usando statsmodels.

# %%
import statsmodels.api as sm
import scipy.stats as stats
a=1
expon_dist = stats.expon(scale=a)

fig = sm.qqplot(vals, dist=expon_dist, line='45')

plt.title("Exp teorica con lamda=1")
plt.show()

# %% [markdown]
# QQ plot contra exp(0.1)

# %%
import statsmodels.api as sm
import scipy.stats as stats
expon_dist = stats.expon(scale=0.1)

# Generar el QQ plot comparando los datos 'vals' con la distribución exponencial personalizada
fig = sm.qqplot(vals, dist=expon_dist, line='45')

plt.title("Exp teorica con lamda=0.1")
plt.show()

# %% [markdown]
# QQ plot contra exp(0.5)

# %%
import statsmodels.api as sm
import scipy.stats as stats
expon_dist = stats.expon(scale=0.5)

# Generar el QQ plot comparando los datos 'vals' con la distribución exponencial personalizada
fig = sm.qqplot(vals, dist=expon_dist, line='45')

plt.title("Exp teorica con lamda=0.5")
plt.show()

# %%
import matplotlib.pyplot as plt
# histograma
count, bins, ignored = plt.hist(x=vals, bins=30, density=True)

# densidad exp(1)
x= np.arange(1,5,0.001)
plt.plot(x, expon.pdf(x,1),lw=2)

plt.title('Tiempos de servicio')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()
